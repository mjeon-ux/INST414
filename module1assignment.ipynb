# %%
import pandas as pd
from tabulate import tabulate

data = pd.read_csv("/Users/michaeljeon/Desktop/INST414/Module 1 Assignment/dataset.csv")

clean_data = data.drop(['index', 'track_id', 'album_name', 'danceability', 
                        'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'], axis=1)

sorted_data = clean_data.sort_values(by='popularity', ascending=False)

print(sorted_data.head(10))
# Out:
#                        artists                             track_name  \
# 20001     Sam Smith;Kim Petras              Unholy (feat. Kim Petras)
# 81051     Sam Smith;Kim Petras              Unholy (feat. Kim Petras)
# 51664         Bizarrap;Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52
# 81210  David Guetta;Bebe Rexha                        I'm Good (Blue)
# 89411            Manuel Turizo                             La Bachata
# 68303            Manuel Turizo                             La Bachata
# 88410            Manuel Turizo                             La Bachata
# 30003  David Guetta;Bebe Rexha                        I'm Good (Blue)
# 20008  David Guetta;Bebe Rexha                        I'm Good (Blue)
# 67356            Manuel Turizo                             La Bachata
#
#        popularity  duration_ms  explicit  energy track_genre
# 20001         100       156943     False   0.472       dance
# 81051         100       156943     False   0.472         pop
# 51664          99       198937     False   0.782     hip-hop
# 81210          98       175238      True   0.965         pop
# 89411          98       162637     False   0.679   reggaeton
# 68303          98       162637     False   0.679      latino
# 88410          98       162637     False   0.679      reggae
# 30003          98       175238      True   0.965         edm
# 20008          98       175238      True   0.965       dance
# 67356          98       162637     False   0.679       latin

# %%
print(tabulate(sorted_data.head(20), headers='keys'))
# Out:
#        artists                     track_name                               popularity    duration_ms  explicit      energy  track_genre
# -----  --------------------------  -------------------------------------  ------------  -------------  ----------  --------  -------------
# 20001  Sam Smith;Kim Petras        Unholy (feat. Kim Petras)                       100         156943  False          0.472  dance
# 81051  Sam Smith;Kim Petras        Unholy (feat. Kim Petras)                       100         156943  False          0.472  pop
# 51664  Bizarrap;Quevedo            Quevedo: Bzrp Music Sessions, Vol. 52            99         198937  False          0.782  hip-hop
# 81210  David Guetta;Bebe Rexha     I'm Good (Blue)                                  98         175238  True           0.965  pop
# 89411  Manuel Turizo               La Bachata                                       98         162637  False          0.679  reggaeton
# 68303  Manuel Turizo               La Bachata                                       98         162637  False          0.679  latino
# 88410  Manuel Turizo               La Bachata                                       98         162637  False          0.679  reggae
# 30003  David Guetta;Bebe Rexha     I'm Good (Blue)                                  98         175238  True           0.965  edm
# 20008  David Guetta;Bebe Rexha     I'm Good (Blue)                                  98         175238  True           0.965  dance
# 67356  Manuel Turizo               La Bachata                                       98         162637  False          0.679  latin
# 68305  Bad Bunny;Chencho Corleone  Me Porto Bonito                                  97         178567  True           0.712  latino
# 68304  Bad Bunny                   Tití Me Preguntó                                 97         243716  False          0.715  latino
# 89405  Bad Bunny                   Tití Me Preguntó                                 97         243716  False          0.715  reggaeton
# 89407  Bad Bunny;Chencho Corleone  Me Porto Bonito                                  97         178567  True           0.712  reggaeton
# 88407  Bad Bunny                   Tití Me Preguntó                                 97         243716  False          0.715  reggae
# 88405  Bad Bunny;Chencho Corleone  Me Porto Bonito                                  97         178567  True           0.712  reggae
# 67358  Bad Bunny;Chencho Corleone  Me Porto Bonito                                  97         178567  True           0.712  latin
# 67359  Bad Bunny                   Tití Me Preguntó                                 97         243716  False          0.715  latin
# 68359  Bad Bunny                   Efecto                                           96         213061  False          0.475  latino
# 81174  OneRepublic                 I Ain't Worried                                  96         148485  False          0.797  pop

# %%
print(data.isnull().sum())
print(data.dtypes)
print("Duplicates: ", data.duplicated().sum())
# Out:
# index               0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64
# index                 int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object
# Duplicates:  0
