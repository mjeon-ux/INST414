# %%
import pandas as pd
from tabulate import tabulate
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans

data = pd.read_csv("/Users/michaeljeon/Desktop/INST414/Module 1 Assignment/dataset.csv")

clean_data = data.drop(['index', 'track_id', 'album_name', 'danceability', 
                        'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
                        'liveness', 'valence', 'tempo', 'time_signature'], axis=1).dropna().drop_duplicates(subset="track_name", keep="first")

sorted_data = clean_data.sort_values(by='popularity', ascending=False)

print(tabulate(sorted_data.head(20), headers='keys'))
print("Total Number of Entries: ", len(sorted_data))
# Out:
#        artists                      track_name                                 popularity    duration_ms  explicit      energy  track_genre
# -----  ---------------------------  ---------------------------------------  ------------  -------------  ----------  --------  -------------
# 20001  Sam Smith;Kim Petras         Unholy (feat. Kim Petras)                         100         156943  False          0.472  dance
# 51664  Bizarrap;Quevedo             Quevedo: Bzrp Music Sessions, Vol. 52              99         198937  False          0.782  hip-hop
# 20008  David Guetta;Bebe Rexha      I'm Good (Blue)                                    98         175238  True           0.965  dance
# 67356  Manuel Turizo                La Bachata                                         98         162637  False          0.679  latin
# 67359  Bad Bunny                    Tití Me Preguntó                                   97         243716  False          0.715  latin
# 67358  Bad Bunny;Chencho Corleone   Me Porto Bonito                                    97         178567  True           0.712  latin
# 79000  OneRepublic                  I Ain't Worried                                    96         148485  False          0.797  piano
# 67559  Bad Bunny                    Efecto                                             96         213061  False          0.475  latin
# 67500  Bad Bunny;Bomba Estéreo      Ojitos Lindos                                      95         258298  False          0.686  latin
# 67603  Bad Bunny                    Moscow Mule                                        94         245939  True           0.674  latin
# 67700  Bad Bunny                    Neverita                                           93         173119  False          0.498  latin
# 15013  Tom Odell                    Another Love                                       93         244360  True           0.537  chill
# 20850  Beyoncé                      CUFF IT                                            93         225388  True           0.689  dance
#  2003  The Neighbourhood            Sweater Weather                                    93         240400  False          0.807  alt-rock
# 81100  Rema;Selena Gomez            Calm Down (with Selena Gomez)                      92         239317  False          0.806  pop
# 38000  Arctic Monkeys               I Wanna Be Yours                                   92         183956  False          0.417  garage
# 20410  Nicki Minaj                  Super Freaky Girl                                  92         170977  True           0.891  dance
# 20017  Charlie Puth;Jung Kook;BTS   Left and Right (Feat. Jung Kook of BTS)            92         154486  False          0.592  dance
# 67801  Rauw Alejandro;Lyanno;Brray  LOKERA                                             91         195294  False          0.828  latin
# 51203  Drake;21 Savage              Jimmy Cooks (feat. 21 Savage)                      91         218364  True           0.673  hip-hop
# Total Number of Entries:  73608

# %%
print(data.isnull().sum())
print(data.dtypes)
print("Duplicates: ", data.duplicated().sum())
# Out:
# index               0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64
# index                 int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object
# Duplicates:  0

# %%
selected_genres = ['hip-hop', 'pop', 'dance']

possible_genre_cols = ['genre', 'genres', 'track_genre']
genre_column = None
for col in possible_genre_cols:
    if col in data.columns:
        genre_column = col
        break

if genre_column is None:
    raise ValueError("No genre column found.")


top_genre_data = data[data[genre_column].isin(selected_genres)].copy()

print("\nSelected Genres Used in Analysis:")
print(selected_genres)


genre_features = ['popularity', 'energy', 'danceability', 'tempo', 'valence']

top_genre_centroids = (
    top_genre_data.groupby(genre_column)[genre_features]
    .mean()
    .reset_index()
)

print("\nTOP GENRE CENTROIDS (RAW):")
print(tabulate(top_genre_centroids, headers="keys"))

scaler_top = StandardScaler()
scaled_centroids = scaler_top.fit_transform(top_genre_centroids[genre_features])

similarity_matrix = cosine_similarity(scaled_centroids)

similarity_df = pd.DataFrame(
    similarity_matrix,
    index=top_genre_centroids[genre_column],
    columns=top_genre_centroids[genre_column]
)

print("\nCosine Similarity Among SELECTED Genres:")
print(tabulate(similarity_df, headers="keys"))




pop_values = sorted_data[['popularity']].values

kmeans = KMeans(n_clusters=3, random_state=42)
sorted_data['popularity_cluster'] = kmeans.fit_predict(pop_values)

cluster_means = (
    sorted_data.groupby('popularity_cluster')['popularity']
    .mean()
    .sort_values()
)

cluster_map = {old:new for new, old in enumerate(cluster_means.index)}
sorted_data['popularity_cluster'] = sorted_data['popularity_cluster'].map(cluster_map)


cluster_summary = (
    sorted_data.groupby('popularity_cluster')['popularity']
    .agg(['mean', 'count'])
    .reset_index()
)

print("\n Popularity Clusters for SELECTED Genres:")
print(tabulate(cluster_summary, headers='keys'))

genre_cluster_distribution = (
    sorted_data.groupby([genre_column, 'popularity_cluster'])['popularity']
    .count()
    .reset_index()
    .rename(columns={'popularity': 'count'})
)

print("\nGenre Distribution Across Popularity Clusters:")
print(tabulate(genre_cluster_distribution, headers='keys'))
# Out:
# Selected Genres Used in Analysis:
# ['hip-hop', 'pop', 'dance']
#
# TOP GENRE CENTROIDS (RAW):
#     track_genre      popularity    energy    danceability    tempo    valence
# --  -------------  ------------  --------  --------------  -------  ---------
#  0  dance                22.69   0.708583        0.687856  120.128   0.552541
#  1  hip-hop              37.759  0.68253         0.736154  116.77    0.551248
#  2  pop                  47.576  0.606437        0.630441  120.927   0.506223
#
# Cosine Similarity Among SELECTED Genres:
# track_genre         dance     hip-hop        pop
# -------------  ----------  ----------  ---------
# dance           1           0.0217416  -0.689214
# hip-hop         0.0217416   1          -0.739372
# pop            -0.689214   -0.739372    1
#
#  Popularity Clusters for SELECTED Genres:
#       popularity_cluster     mean    count
# --  --------------------  -------  -------
#  0                     0  14.6696    27915
#  1                     1  38.261     28580
#  2                     2  60.0782    17113
#
# Genre Distribution Across Popularity Clusters:
#      track_genre          popularity_cluster    count
# ---  -----------------  --------------------  -------
#   0  acoustic                              0      116
#   1  acoustic                              1      408
#   2  acoustic                              2      387
#   3  afrobeat                              0      663
#   4  afrobeat                              1      255
#   5  afrobeat                              2       27
#   6  alt-rock                              0      268
#   7  alt-rock                              1      202
#   8  alt-rock                              2      307
#   9  alternative                           0      105
#  10  alternative                           1       11
#  11  alternative                           2      108
#  12  ambient                               0      124
#  13  ambient                               1      295
#  14  ambient                               2      477
#  15  anime                                 0       40
#  16  anime                                 1      409
#  17  anime                                 2      476
#  18  black-metal                           0      829
#  19  black-metal                           1      139
#  20  black-metal                           2       13
#  21  bluegrass                             0      667
#  22  bluegrass                             1      234
#  23  bluegrass                             2       29
#  24  blues                                 0      145
#  25  blues                                 1      239
#  26  blues                                 2      266
#  27  brazil                                0       30
#  28  brazil                                1      764
#  29  brazil                                2      114
#  30  breakbeat                             0      716
#  31  breakbeat                             1      167
#  32  breakbeat                             2       31
#  33  british                               0      163
#  34  british                               1      192
#  35  british                               2      447
#  36  cantopop                              0      341
#  37  cantopop                              1      449
#  38  cantopop                              2      145
#  39  chicago-house                         0      846
#  40  chicago-house                         1       64
#  41  chicago-house                         2        6
#  42  children                              0      157
#  43  children                              1      458
#  44  children                              2      159
#  45  chill                                 0       26
#  46  chill                                 1      128
#  47  chill                                 2      667
#  48  classical                             0      531
#  49  classical                             1      174
#  50  classical                             2       40
#  51  club                                  0      325
#  52  club                                  1      463
#  53  club                                  2       83
#  54  comedy                                0      831
#  55  comedy                                1      104
#  56  comedy                                2       30
#  57  country                               0      278
#  58  country                               1      112
#  59  country                               2      117
#  60  dance                                 0      210
#  61  dance                                 2      186
#  62  dancehall                             0      196
#  63  dancehall                             1      332
#  64  dancehall                             2      250
#  65  death-metal                           0      474
#  66  death-metal                           1      191
#  67  death-metal                           2      160
#  68  deep-house                            0       95
#  69  deep-house                            1      219
#  70  deep-house                            2      451
#  71  detroit-techno                        0      777
#  72  detroit-techno                        1       79
#  73  detroit-techno                        2        5
#  74  disco                                 0      166
#  75  disco                                 1      356
#  76  disco                                 2      190
#  77  disney                                0      598
#  78  disney                                1      223
#  79  disney                                2       74
#  80  drum-and-bass                         0      558
#  81  drum-and-bass                         1      118
#  82  drum-and-bass                         2       97
#  83  dub                                   0      118
#  84  dub                                   1      410
#  85  dub                                   2      199
#  86  dubstep                               0       15
#  87  dubstep                               1      175
#  88  dubstep                               2       15
#  89  edm                                   0       91
#  90  edm                                   1       45
#  91  edm                                   2      280
#  92  electro                               0      101
#  93  electro                               1       14
#  94  electro                               2      208
#  95  electronic                            0       54
#  96  electronic                            1      368
#  97  electronic                            2      291
#  98  emo                                   0       23
#  99  emo                                   1      342
# 100  emo                                   2      411
# 101  folk                                  0       62
# 102  folk                                  1      416
# 103  folk                                  2      196
# 104  forro                                 1      875
# 105  forro                                 2       50
# 106  french                                0       65
# 107  french                                1      445
# 108  french                                2      245
# 109  funk                                  0       98
# 110  funk                                  1      357
# 111  funk                                  2      130
# 112  garage                                0      198
# 113  garage                                1      258
# 114  garage                                2      307
# 115  german                                0      141
# 116  german                                1      329
# 117  german                                2      114
# 118  gospel                                0        1
# 119  gospel                                1      620
# 120  goth                                  0      492
# 121  goth                                  1      249
# 122  goth                                  2       66
# 123  grindcore                             0      908
# 124  grindcore                             1       16
# 125  groove                                0      152
# 126  groove                                1      259
# 127  groove                                2      116
# 128  grunge                                0       71
# 129  grunge                                1      149
# 130  grunge                                2      377
# 131  guitar                                0      436
# 132  guitar                                1      300
# 133  guitar                                2       35
# 134  happy                                 0      739
# 135  happy                                 1      101
# 136  happy                                 2       42
# 137  hard-rock                             0       51
# 138  hard-rock                             1      282
# 139  hard-rock                             2      229
# 140  hardcore                              0       65
# 141  hardcore                              1      415
# 142  hardcore                              2      179
# 143  hardstyle                             0      522
# 144  hardstyle                             1      142
# 145  hardstyle                             2       99
# 146  heavy-metal                           0      639
# 147  heavy-metal                           1      270
# 148  heavy-metal                           2       35
# 149  hip-hop                               0      115
# 150  hip-hop                               1        1
# 151  hip-hop                               2      491
# 152  honky-tonk                            0      710
# 153  honky-tonk                            1       49
# 154  honky-tonk                            2       11
# 155  house                                 0       22
# 156  house                                 1        7
# 157  house                                 2       69
# 158  idm                                   0      747
# 159  idm                                   1      131
# 160  indian                                0       20
# 161  indian                                1      339
# 162  indian                                2      328
# 163  indie                                 0       26
# 164  indie                                 1       30
# 165  indie                                 2       37
# 166  indie-pop                             0       91
# 167  indie-pop                             1      105
# 168  indie-pop                             2      220
# 169  industrial                            0      431
# 170  industrial                            1      113
# 171  industrial                            2      147
# 172  iranian                               0      855
# 173  iranian                               1        4
# 174  j-dance                               0      507
# 175  j-dance                               1       90
# 176  j-dance                               2       39
# 177  j-idol                                0      660
# 178  j-idol                                1      211
# 179  j-idol                                2       22
# 180  j-pop                                 0       53
# 181  j-pop                                 1      322
# 182  j-pop                                 2      170
# 183  j-rock                                0        4
# 184  j-rock                                1      373
# 185  j-rock                                2       43
# 186  jazz                                  0       93
# 187  jazz                                  1       33
# 188  jazz                                  2       40
# 189  k-pop                                 0        6
# 190  k-pop                                 1      213
# 191  k-pop                                 2      557
# 192  kids                                  0      664
# 193  kids                                  1       77
# 194  kids                                  2        8
# 195  latin                                 0      327
# 196  latin                                 1        1
# 197  latin                                 2       68
# 198  latino                                0       30
# 199  latino                                1      147
# 200  latino                                2      130
# 201  malay                                 0      386
# 202  malay                                 1      476
# 203  malay                                 2       59
# 204  mandopop                              0      135
# 205  mandopop                              1      284
# 206  mandopop                              2      373
# 207  metal                                 0       11
# 208  metal                                 1       45
# 209  metal                                 2      118
# 210  metalcore                             0      124
# 211  metalcore                             1      133
# 212  metalcore                             2      257
# 213  minimal-techno                        0      262
# 214  minimal-techno                        1      382
# 215  minimal-techno                        2       79
# 216  mpb                                   0       15
# 217  mpb                                   1      690
# 218  mpb                                   2       12
# 219  new-age                               0      496
# 220  new-age                               1      235
# 221  new-age                               2       67
# 222  opera                                 0      553
# 223  opera                                 1       80
# 224  opera                                 2       59
# 225  pagode                                0        2
# 226  pagode                                1      647
# 227  pagode                                2      127
# 228  party                                 0      340
# 229  party                                 1      282
# 230  party                                 2        6
# 231  piano                                 0       28
# 232  piano                                 1      193
# 233  piano                                 2      314
# 234  pop                                   0       45
# 235  pop                                   1        1
# 236  pop                                   2      189
# 237  pop-film                              0       24
# 238  pop-film                              1       20
# 239  pop-film                              2      720
# 240  power-pop                             0      582
# 241  power-pop                             1      109
# 242  power-pop                             2       60
# 243  progressive-house                     0       48
# 244  progressive-house                     1      186
# 245  progressive-house                     2      294
# 246  psych-rock                            0       56
# 247  psych-rock                            1      224
# 248  psych-rock                            2      209
# 249  punk                                  0       12
# 250  punk                                  1      129
# 251  punk                                  2       40
# 252  punk-rock                             0       31
# 253  punk-rock                             1      418
# 254  punk-rock                             2       92
# 255  r-n-b                                 0       30
# 256  r-n-b                                 1      302
# 257  r-n-b                                 2       69
# 258  reggae                                0       66
# 259  reggae                                1       40
# 260  reggae                                2       36
# 261  reggaeton                             0        3
# 262  reggaeton                             1       41
# 263  reggaeton                             2       12
# 264  rock                                  0       74
# 265  rock                                  1        1
# 266  rock                                  2       41
# 267  rock-n-roll                           0       11
# 268  rock-n-roll                           1      580
# 269  rock-n-roll                           2      104
# 270  rockabilly                            0      254
# 271  rockabilly                            1      143
# 272  rockabilly                            2       70
# 273  romance                               0      782
# 274  romance                               1       24
# 275  sad                                   0       11
# 276  sad                                   1      136
# 277  sad                                   2      283
# 278  salsa                                 0       71
# 279  salsa                                 1      769
# 280  salsa                                 2        8
# 281  samba                                 0       16
# 282  samba                                 1      532
# 283  samba                                 2        7
# 284  sertanejo                             1      539
# 285  sertanejo                             2      223
# 286  show-tunes                            0      426
# 287  show-tunes                            1      182
# 288  show-tunes                            2      135
# 289  singer-songwriter                     0       26
# 290  singer-songwriter                     1      114
# 291  singer-songwriter                     2      210
# 292  ska                                   0        8
# 293  ska                                   1      668
# 294  ska                                   2        3
# 295  sleep                                 0      161
# 296  sleep                                 1      515
# 297  sleep                                 2      215
# 298  soul                                  0       63
# 299  soul                                  1        9
# 300  soul                                  2      121
# 301  spanish                               0      111
# 302  spanish                               1      391
# 303  spanish                               2      304
# 304  study                                 0      396
# 305  study                                 1      493
# 306  study                                 2       13
# 307  swedish                               0       49
# 308  swedish                               1      412
# 309  swedish                               2      118
# 310  synth-pop                             0      253
# 311  synth-pop                             1      180
# 312  synth-pop                             2      172
# 313  tango                                 0      676
# 314  tango                                 1       73
# 315  techno                                0       52
# 316  techno                                1      189
# 317  techno                                2       76
# 318  trance                                0       52
# 319  trance                                1      420
# 320  trance                                2      102
# 321  trip-hop                              0      352
# 322  trip-hop                              1      221
# 323  trip-hop                              2      160
# 324  turkish                               0       11
# 325  turkish                               1      757
# 326  turkish                               2       28
# 327  world-music                           0      133
# 328  world-music                           1      447
# 329  world-music                           2      182
